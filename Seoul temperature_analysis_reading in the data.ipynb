# %%
import csv
f = open("./data/1930_2020_seoul_temp_data.csv", 'r', encoding='cp949')
data = csv.reader(f, delimiter=',')
print(data)
f.close()

# %%
import csv
g = open("./data/1930_2020_seoul_temp_data.csv", encoding='cp949')
data1=csv.reader(g)
for row in data1:
    print(row)
g.close()
# Out:
# ['Location Code', 'Location', 'Date', 'Average Temp.(℃)', 'Highest Temp.(℃)', 'Lowest Temp.(℃)']
# ['108', 'Seoul', '1/1/1930', '-1.6', '2.9', '-6.9']
# ['108', 'Seoul', '1/2/1930', '0.6', '3.3', '-3.3']
# ['108', 'Seoul', '1/3/1930', '-2.8', '1.6', '-6.4']
# ['108', 'Seoul', '1/4/1930', '-11', '-5.8', '-13.4']
# ['108', 'Seoul', '1/5/1930', '-11.6', '-6.9', '-16.1']
# ['108', 'Seoul', '1/6/1930', '-12.2', '-7.8', '-17.4']
# ['108', 'Seoul', '1/7/1930', '-9.8', '-5.3', '-16.8']
# ['108', 'Seoul', '1/8/1930', '-9.8', '-5.5', '-13.6']
# ['108', 'Seoul', '1/9/1930', '-10.5', '-5.2', '-16']
# ['108', 'Seoul', '1/10/1930', '-4.5', '0.9', '-11.5']
# ['108', 'Seoul', '1/11/1930', '-4.2', '0.7', '-8.3']
# ['108', 'Seoul', '1/12/1930', '-6.4', '-0.7', '-12.5']
# ['108', 'Seoul', '1/13/1930', '-5.6', '0.2', '-14.4']
# ['108', 'Seoul', '1/14/1930', '-2.4', '2.5', '-5.2']
# ['108', 'Seoul', '1/15/1930', '-3.9', '1.4', '-10.1']
# ['108', 'Seoul', '1/16/1930', '-3.3', '2.4', '-7.6']
# ...

# %%
#Each row is in []: this means that each row is a 'list'
##Indexing and slicing can be done to a 'list'

#Each item is in ' ': this means that each item is 'String'
#When I need to use the data, I need these converted to 'float'

# %%
#header: row that shows what the meaning of the data/values
#next() function can be used to save header

##next() function: 1. reads the first row, 2. move to the next row

import csv
h = open("./data/1930_2020_seoul_temp_data.csv", encoding="cp949")
data=csv.reader(h)
header=next(data) 
print(header)    
h.close()
# Out:
# ['Location Code', 'Location', 'Date', 'Average Temp.(℃)', 'Highest Temp.(℃)', 'Lowest Temp.(℃)']

# %%
import csv
h = open("./data/1930_2020_seoul_temp_data.csv", encoding="cp949")
data=csv.reader(h)

header=next(data)
for row in data: 
    print(row)
h.close()
# Out:
# ['108', 'Seoul', '1/1/1930', '-1.6', '2.9', '-6.9']
# ['108', 'Seoul', '1/2/1930', '0.6', '3.3', '-3.3']
# ['108', 'Seoul', '1/3/1930', '-2.8', '1.6', '-6.4']
# ['108', 'Seoul', '1/4/1930', '-11', '-5.8', '-13.4']
# ['108', 'Seoul', '1/5/1930', '-11.6', '-6.9', '-16.1']
# ['108', 'Seoul', '1/6/1930', '-12.2', '-7.8', '-17.4']
# ['108', 'Seoul', '1/7/1930', '-9.8', '-5.3', '-16.8']
# ['108', 'Seoul', '1/8/1930', '-9.8', '-5.5', '-13.6']
# ['108', 'Seoul', '1/9/1930', '-10.5', '-5.2', '-16']
# ['108', 'Seoul', '1/10/1930', '-4.5', '0.9', '-11.5']
# ['108', 'Seoul', '1/11/1930', '-4.2', '0.7', '-8.3']
# ['108', 'Seoul', '1/12/1930', '-6.4', '-0.7', '-12.5']
# ['108', 'Seoul', '1/13/1930', '-5.6', '0.2', '-14.4']
# ['108', 'Seoul', '1/14/1930', '-2.4', '2.5', '-5.2']
# ['108', 'Seoul', '1/15/1930', '-3.9', '1.4', '-10.1']
# ['108', 'Seoul', '1/16/1930', '-3.3', '2.4', '-7.6']
# ['108', 'Seoul', '1/17/1930', '-4.3', '1.6', '-11.7']
# ['108', 'Seoul', '1/18/1930', '-4.3', '0.1', '-8.4']
# ...
